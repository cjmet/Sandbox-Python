# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Sample data: house sizes in square feet and prices in dollars
budget = np.array([1000, 1200, 1400, 1600, 1800, 2000, 2200, 2400, 2600, 2800]).reshape(-1, 1)
sales = np.array([200000, 220000, 240000, 260000, 280000, 300000, 320000, 340000, 360000, 380000])

# Split data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(budget, sales, test_size=0.2, random_state=42)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict prices for the test set
y_pred = model.predict(X_test)

# Calculate mean squared error to evaluate model accuracy
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Make predictions for specific house sizes
prediction_sizes = np.array([1500, 3000]).reshape(-1, 1)
predictions = model.predict(prediction_sizes)

print(f"\nPredictions:")
print(f"1500 sq ft house: ${predictions[0]:,.2f}")
print(f"3000 sq ft house: ${predictions[1]:,.2f}")

# Visualize the results
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.scatter(prediction_sizes, predictions, color='orange', label='Predictions')
plt.plot(X_train, model.predict(X_train), color='red', label='Regression line')
plt.xlabel('House Size (sq ft)')
plt.ylabel('House Price ($)')
plt.title('Simple Linear Regression: House Price vs. Size')
plt.legend()
plt.show()

#print the slope and intercept
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")

# Caclulate r-squared value
r_squared = model.score(X_test, y_test)
print(f"R-squared: {r_squared}")

# compare to MSE, which is already printed above
print(f"Mean Squared Error (MSE): {mse}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Sample data: house sizes in square feet and prices in dollars
budget = np.array([50, 60, 70, 80, 90, 100]).reshape(-1, 1)
sales = np.array([150, 180, 210, 240, 270, 300])

# Split data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(budget, sales, test_size=0.2, random_state=42)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict prices for the test set
y_pred = model.predict(X_test)

# Calculate mean squared error to evaluate model accuracy
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Make predictions for specific sizes/budgets
prediction_sizes = np.array([75, 95]).reshape(-1, 1)
predictions = model.predict(prediction_sizes)

print(f"\nPredictions:")
print(f"$75,000 Budget: ${predictions[0]:,.2f}")
print(f"$95,000 Budget:: ${predictions[1]:,.2f}")


# Visualize the results
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.scatter(prediction_sizes, predictions, color='orange', label='Predictions')
plt.plot(X_train, model.predict(X_train), color='red', label='Regression line')
plt.xlabel('Advertising Budget')
plt.ylabel('Sales ($)')
plt.title('Simple Linear Regression: Advertising Budget vs. Sales')
plt.legend()
plt.show()

#print the slope and intercept
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")

# Caclulate r-squared value
r_squared = model.score(X_test, y_test)
print(f"R-squared: {r_squared}")

# compare to MSE, which is already printed above
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error: 0.0
#
# Predictions:
# $75,000 Budget: $225.00
# $95,000 Budget:: $285.00
# Slope (m): 3.0000000000000004
# Intercept (b): -2.842170943040401e-14
# R-squared: 1.0
# Mean Squared Error (MSE): 0.0
